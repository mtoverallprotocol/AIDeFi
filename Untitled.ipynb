# %%
# plot test

# %%
# Run User Functions
#
# Import classes:
from classes import blockchain_v1_0_0_0 as blockchain # import class file
blockchain = blockchain.blockchain() # inizialize class in blockchain variable

# %%
logFile = 'data/contracts/smartContractsLogsGrouped_20210712_170625.csv'
indexColumns = [1, 13, 29, 30, 32, 47, 69, 90]
import pandas as pd
logFileDf = pd.read_csv(logFile)
logFileDf = logFileDf[int(len(logFileDf) * (72 / 100)):]
index = 0
for indexKey in logFileDf.keys():
    print('{} - {}'.format(index, indexKey))
    index = index + 1
blockchain.plotLogs(indexColumns, logFileDf, True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2,4,6,7,9,10,11,12,13,14,16,17,18,22,27,29,32,33,35,36,37,38,39,41,42,43,45,46,47,48,50,51,53,55,56,58,60,61,62,63,65,67,68,70,72,73,74,76,77,78,80,81,82,84,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 0 - Unnamed: 0
# 1 - blockNumber
# 2 - A3E8E4_RESERVESADDED_timestamp_iso8601
# 3 - A3E8E4_RESERVESADDED_timestamp_unixtime
# 4 - A3E8E4_RESERVESADDED_benefactor
# 5 - A3E8E4_RESERVESADDED_addAmount
# 6 - A3E8E4_RESERVESADDED_newTotalReserves
# 7 - A3E8E4_REPAYBORROW_timestamp_iso8601
# 8 - A3E8E4_REPAYBORROW_timestamp_unixtime
# 9 - A3E8E4_REPAYBORROW_payer
# 10 - A3E8E4_REPAYBORROW_borrower
# 11 - A3E8E4_REPAYBORROW_repayAmount
# 12 - A3E8E4_REPAYBORROW_accountBorrows
# 13 - A3E8E4_REPAYBORROW_totalBorrows
# 14 - A3E8E4_NEWIMPLEMENTATION_timestamp_iso8601
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

logs = pd.read_csv('data/contracts/smartContractsLogsGrouped_20210712_170625.csv')
index = 0
for indexKey in logs.keys():
    print('{} - {}'.format(index, indexKey))
    index = index + 1

# Reduce space to percentage
logs = logs[int(len(logs) * (50 / 100)):]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2,4,6,7,9,10,11,12,13,14,16,17,18,22,27,29,32,33,35,36,37,38,39,41,42,43,45,46,47,48,50,51,53,55,56,58,60,61,62,63,65,67,68,70,72,73,74,76,77,78,80,81,82,84,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 0 - Unnamed: 0
# 1 - blockNumber
# 2 - A3E8E4_RESERVESADDED_timestamp_iso8601
# 3 - A3E8E4_RESERVESADDED_timestamp_unixtime
# 4 - A3E8E4_RESERVESADDED_benefactor
# 5 - A3E8E4_RESERVESADDED_addAmount
# 6 - A3E8E4_RESERVESADDED_newTotalReserves
# 7 - A3E8E4_REPAYBORROW_timestamp_iso8601
# 8 - A3E8E4_REPAYBORROW_timestamp_unixtime
# 9 - A3E8E4_REPAYBORROW_payer
# 10 - A3E8E4_REPAYBORROW_borrower
# 11 - A3E8E4_REPAYBORROW_repayAmount
# 12 - A3E8E4_REPAYBORROW_accountBorrows
# 13 - A3E8E4_REPAYBORROW_totalBorrows
# 14 - A3E8E4_NEWIMPLEMENTATION_timestamp_iso8601
# ...

# %%
columnsIndex = [1, 13, 47]
plt.figure(figsize = (16,8))
fig, axs = plt.subplots(len(columnsIndex), 1, figsize=(16, 5*len(columnsIndex)), sharex=True, sharey=False)
i = 0
columns = []
cond = []
names = []
values = []

for index in columnsIndex :
    try:
        columns.append(logs.keys()[index])
        print(columns[i])
        cond.append(logs[columns[i]].fillna(0).astype(float) > 0)
        names.append(list(logs[cond[i]]['blockNumber'].astype(float)))
        values.append(list(logs[cond[i]][columns[i]]))
        axs[i].scatter(names[i], values[i])
        axs[i].set_title(columns[i] + ' - min: ' + str(min(values[i])) + ' - max: ' + str(max(values[i]))) #add min max
        axs[i].axes.get_yaxis().set_visible(False)
        i = i + 1
    except:
        print('Error on: {}'.format(index))

fig.suptitle('Categorical Plotting')
# Out:
# blockNumber
# A3E8E4_REPAYBORROW_totalBorrows
# A3E8E4_APPROVAL_amount
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
fig.savefig('testGraph.pdf')

# %%
from classes import models_v1_0_0_0 as models
models = models.models()

# %%
logs[cond1].filter([column1])

# %%
models.modelBase(logs[cond1].filter([column1]), 60, .8, 10, True)

# %%
import time

_functionName = 'test'
import os.path
listenerID = _functionName
openListener = 'classes/listeners/open_{}.listener'.format(listenerID) # only for the first call of the function
openState = 0

f = open(openListener,'w')
f.close()
isLoop = True

while isLoop:
    try:
        f = open(openListener,'r')
        f.close()
        openState = 1
    except:
        isLoop = False
        print('Listener Stopped')
        openState = 2
    finally:
        if openState == 1: #the file was removed
            print('A') #do something
            time.sleep(3) #3 seconds
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# Listener Stopped
