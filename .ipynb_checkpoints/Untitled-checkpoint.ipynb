# %%
from core import AIDeFiCore
from query import sqlQueries
import pandasql as ps
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-b03113b20561> in <module>
#       1 from core import AIDeFiCore
#       2 from query import sqlQueries
# ----> 3 from pandasql import ps
#
# ImportError: cannot import name 'ps' from 'pandasql' (/opt/anaconda3/lib/python3.8/site-packages/pandasql/__init__.py)

# %%
connectionString = 'https://ropsten.infura.io/v3/9a82d6f712b6474eb712fa507d110055'

# %%
ai = AIDeFiCore.AIDeFiCore()

# %%
w3 = ai.blockchainConnection(connectionString)

# %%
w3.isConnected()
# Out:
# True

# %%
lastBlockNumber = ai.getLastBlockNumber(w3)
df = ai.importBlockInterval(w3, lastBlockNumber - 100, lastBlockNumber)

# %%
df
# Out:
#     difficulty                                          extraData gasLimit  \
# 1    658101908  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 2    658423502  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 3    658423758  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 4    658745509  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 5    658424112  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# ..         ...                                                ...      ...
# 96   656825227  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 97   657146198  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 98   657467326  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 99   657467582  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
# 100  657146809  0x7c9b97b3d1fcddb478e48de0d060c625439444706274...  8000000
#
#      gasUsed                                               hash  \
# ...

# %%
queries = sqlQueries.sqlQueries()
table = ps.sqldf(queries.selectAll("df"), locals())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b43b642b2ef1> in <module>
#       1 queries = sqlQueries.sqlQueries()
# ----> 2 table = ps.sqldf(queries.selectAll("df"), locals())
#
# NameError: name 'ps' is not defined
